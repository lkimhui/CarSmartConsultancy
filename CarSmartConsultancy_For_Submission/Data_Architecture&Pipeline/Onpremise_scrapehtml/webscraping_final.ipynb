# %%
# import libraries
from bs4 import BeautifulSoup
import requests as req
import pickle
import re
import pandas as pd
import numpy as np
import functools
import operator
import datetime
import os

# %%
# define a function which scrape url based on number of pages

# subfunction 1
def get_carModelUrl(url):
    html = req.get(url)
    soup = BeautifulSoup(html.content, 'lxml')
    href = soup.body.find('div', {'id':'content'}).find('form', {'name':'searchform'}).next_sibling.next_sibling.find_all(href=re.compile(r"(^(info.php).*)"), string=True)
    return href

# subfunction 2
def get_keypairs(hrefString):
    
    idValue = re.search("(?<=\?ID=)\d+(?=\&)", str(hrefString))
    dlValue = re.search("(?<=\;DL=)\d+(?=(\"|\&))", str(hrefString))
    
    return idValue[0].strip(), dlValue[0].strip()

# main function 1: get the webpage url
def scrape_url(page):
    
    #convert page to list of car per page
    pageToList = [(i+1)*100 for i in range(page)]
    
    #create BeautifulSoup object
    urlList = [f"https://www.sgcarmart.com/used_cars/listing.php?BRSR={car}&RPG=100" for car in pageToList]
    carModelUrlList = list(map(get_carModelUrl, urlList))
    
    #flatten the list
    carModelUrlList = functools.reduce(operator.iconcat, carModelUrlList, [])
    
    #get keypairs(id-dl)
    keypairsList = list(map(get_keypairs, carModelUrlList))
    
    #reformat the webpage url
    carModelUrlList = list(map(lambda x: f"https://www.sgcarmart.com/used_cars/info.php?ID={x[0]}&DL={x[1]}", keypairsList))
    
    return carModelUrlList

# %%
# run main function 1: get webpage url based o
carModelUrls = scrape_url(20)
# %time
# Out:
# CPU times: total: 0 ns
# Wall time: 719 µs

# %%
# define a function to scrape features from SGCar Mart
def feature_scraping(url):
    print(url)
    # Get the html page
    html = req.get(url)
    soup = BeautifulSoup(html.content, 'lxml')
    filename = f"Y:/Documents/GitHub/CarSmartConsultancy/Data/scrape_data/html_files/car_html_content_{datetime.datetime.now().strftime('%Y-%m-%d_%H-%M-%S')}.html"
    with open(filename, "w") as f:
        # traverse paragraphs from soup
        f.write(str(soup))
    return soup

# %%
features = list(map(feature_scraping, carModelUrls))
# Out:
# https://www.sgcarmart.com/used_cars/info.php?ID=1166804&DL=3403
# https://www.sgcarmart.com/used_cars/info.php?ID=1146395&DL=3403
# https://www.sgcarmart.com/used_cars/info.php?ID=1190809&DL=2189
# https://www.sgcarmart.com/used_cars/info.php?ID=1190807&DL=3562
# https://www.sgcarmart.com/used_cars/info.php?ID=1190806&DL=4052
# https://www.sgcarmart.com/used_cars/info.php?ID=1185439&DL=3946
# https://www.sgcarmart.com/used_cars/info.php?ID=1182534&DL=4162
# https://www.sgcarmart.com/used_cars/info.php?ID=1182307&DL=4162
# https://www.sgcarmart.com/used_cars/info.php?ID=1180925&DL=2410
# https://www.sgcarmart.com/used_cars/info.php?ID=1173419&DL=4162
# https://www.sgcarmart.com/used_cars/info.php?ID=1132256&DL=3403
# https://www.sgcarmart.com/used_cars/info.php?ID=1190805&DL=4225
# https://www.sgcarmart.com/used_cars/info.php?ID=1190803&DL=4060
# https://www.sgcarmart.com/used_cars/info.php?ID=1188087&DL=3142
# https://www.sgcarmart.com/used_cars/info.php?ID=1186449&DL=1264
# https://www.sgcarmart.com/used_cars/info.php?ID=1190804&DL=3106
# https://www.sgcarmart.com/used_cars/info.php?ID=1190801&DL=4398
# https://www.sgcarmart.com/used_cars/info.php?ID=1190802&DL=3951
# https://www.sgcarmart.com/used_cars/info.php?ID=1190052&DL=1094
# https://www.sgcarmart.com/used_cars/info.php?ID=1190014&DL=4405
# https://www.sgcarmart.com/used_cars/info.php?ID=1155928&DL=1111
# https://www.sgcarmart.com/used_cars/info.php?ID=1190800&DL=4343
# https://www.sgcarmart.com/used_cars/info.php?ID=1190799&DL=2690
# https://www.sgcarmart.com/used_cars/info.php?ID=1190796&DL=1000
# https://www.sgcarmart.com/used_cars/info.php?ID=1190798&DL=3122
# https://www.sgcarmart.com/used_cars/info.php?ID=1190795&DL=4202
# https://www.sgcarmart.com/used_cars/info.php?ID=1190797&DL=3167
# https://www.sgcarmart.com/used_cars/info.php?ID=1190794&DL=3122
# https://www.sgcarmart.com/used_cars/info.php?ID=1181707&DL=2003
# https://www.sgcarmart.com/used_cars/info.php?ID=1190793&DL=3417
# https://www.sgcarmart.com/used_cars/info.php?ID=1187188&DL=4360
# https://www.sgcarmart.com/used_cars/info.php?ID=1190792&DL=4162
# https://www.sgcarmart.com/used_cars/info.php?ID=1190790&DL=1000
# https://www.sgcarmart.com/used_cars/info.php?ID=1190789&DL=4189
# https://www.sgcarmart.com/used_cars/info.php?ID=1190791&DL=1013
# https://www.sgcarmart.com/used_cars/info.php?ID=1190778&DL=4140
# https://www.sgcarmart.com/used_cars/info.php?ID=1173250&DL=4240
# https://www.sgcarmart.com/used_cars/info.php?ID=1155659&DL=4240
# https://www.sgcarmart.com/used_cars/info.php?ID=1138195&DL=3647
# https://www.sgcarmart.com/used_cars/info.php?ID=1190786&DL=1094
# https://www.sgcarmart.com/used_cars/info.php?ID=1190784&DL=2291
# https://www.sgcarmart.com/used_cars/info.php?ID=1190781&DL=1000
# https://www.sgcarmart.com/used_cars/info.php?ID=1187989&DL=3100
# https://www.sgcarmart.com/used_cars/info.php?ID=1186897&DL=3293
# https://www.sgcarmart.com/used_cars/info.php?ID=1185640&DL=3100
# https://www.sgcarmart.com/used_cars/info.php?ID=1184506&DL=3100
# https://www.sgcarmart.com/used_cars/info.php?ID=1183745&DL=2440
# https://www.sgcarmart.com/used_cars/info.php?ID=1180297&DL=2725
# https://www.sgcarmart.com/used_cars/info.php?ID=1167764&DL=3100
# https://www.sgcarmart.com/used_cars/info.php?ID=1105087&DL=1111
# https://www.sgcarmart.com/used_cars/info.php?ID=1190785&DL=3282
# https://www.sgcarmart.com/used_cars/info.php?ID=1190783&DL=2799
# https://www.sgcarmart.com/used_cars/info.php?ID=1189440&DL=2440
# https://www.sgcarmart.com/used_cars/info.php?ID=1187492&DL=3100
# https://www.sgcarmart.com/used_cars/info.php?ID=1187283&DL=3100
# https://www.sgcarmart.com/used_cars/info.php?ID=1184490&DL=3100
# https://www.sgcarmart.com/used_cars/info.php?ID=1180888&DL=2440
# https://www.sgcarmart.com/used_cars/info.php?ID=1178281&DL=3100
# https://www.sgcarmart.com/used_cars/info.php?ID=1178163&DL=2725
# https://www.sgcarmart.com/used_cars/info.php?ID=1173534&DL=2440
# https://www.sgcarmart.com/used_cars/info.php?ID=1171499&DL=3100
# https://www.sgcarmart.com/used_cars/info.php?ID=1171311&DL=2725
# https://www.sgcarmart.com/used_cars/info.php?ID=1190776&DL=1000
# https://www.sgcarmart.com/used_cars/info.php?ID=1190510&DL=3043
# https://www.sgcarmart.com/used_cars/info.php?ID=1189443&DL=2440
# https://www.sgcarmart.com/used_cars/info.php?ID=1188439&DL=1111
# https://www.sgcarmart.com/used_cars/info.php?ID=1187671&DL=3875
# https://www.sgcarmart.com/used_cars/info.php?ID=1183825&DL=2440

# %%
# Functions defined to scrape each features
def get_model(soup):
    model = soup.body.find('div', {'id':'contentblank'}).select('div:nth-of-type(2)')[0].select('div:nth-of-type(1)')[0].text.strip()
    return model

def get_price(soup):
    pr = soup.body.find('div', {'id':'main_left'}).find('table', {'id':'carInfo'}).find('tr').find_all('strong')[1]
    pr = str(pr).partition('/')[0].partition('>')[-1].partition('<')[0].strip()
    return pr

def get_depreciation(soup):
    dep = soup.body.find('div', {'id':'main_left'}).find('table', {'id':'carInfo'}).select('tr:nth-of-type(2)')[0].select('td:nth-of-type(2)')[0].find_all(string=re.compile("$"))
    dep = dep[0].replace(" ", "").strip().partition('/')[0]
    return dep

def get_registrationDate(soup):
    regDate = soup.body.find('div', {'id':'main_left'}).find('table', {'id':'carInfo'}).select('tr:nth-of-type(2)')[0].select('td:nth-of-type(4)')[0].find_all(string=True)
    reg = regDate[0].strip()
    return reg

def get_mileage(soup):
    try:
        mi = soup.body.find('div', {'id':'main_left'}).find('table', {'id':'carInfo'}).select('tr:nth-of-type(3)')[0].select('div:nth-of-type(1)')[0].find('div', {'class':'row_info'}).string
        mi = mi.strip()
        return mi
    except:
        return ''

def get_roadTax(soup):
    try:
        roadTax = soup.body.find('div', {'id':'main_left'}).find('table', {'id':'carInfo'}).select('tr:nth-of-type(3)')[0].find('td').select('div:nth-of-type(1)')[0].next_sibling.next_sibling.find('div', {'class':'row_info'}).string
        roadTax = roadTax.strip()
        return roadTax
    except:
        return ''

def get_deregistrationValue(soup):
    try:    
        dereg = soup.body.find('div', {'id':'main_left'}).find('table', {'id':'carInfo'}).select('tr:nth-of-type(3)')[0].find('td').select('div:nth-of-type(3)')[0].find('div', {'class':'row_info'}).find(string=re.compile("$"))
        dereg = dereg.partition("as")[0].strip()
        return dereg
    except:
        return ''

def get_coe(soup):
    try:
        coe = soup.body.find('div', {'id':'main_left'}).find('table', {'id':'carInfo'}).select('tr:nth-of-type(3)')[0].find('td').select('div:nth-of-type(4)')[0].find('div', {'class':'row_info'}).string
        coe = coe.strip()
        return coe
    except:
        return ''
    
def get_engineCap(soup):
    try:
        eng = soup.body.find('div', {'id':'main_left'}).find('table', {'id':'carInfo'}).select('tr:nth-of-type(3)')[0].find('td').select('div:nth-of-type(5)')[0].find('div', {'class':'row_info'}).string
        eng = eng.strip()
        return eng
    except:
        return ''
    
def get_curbWeight(soup):
    try:
        weight = soup.body.find('div', {'id':'main_left'}).find('table', {'id':'carInfo'}).select('tr:nth-of-type(3)')[0].find('td').select('div:nth-of-type(6)')[0].find('div', {'class':'row_info'}).string
        weight = weight.strip()
        return weight
    except:
        return ''
    
def get_manufacturedYear(soup):
    try:
        year = soup.body.find('div', {'id':'main_left'}).find('table', {'id':'carInfo'}).select('tr:nth-of-type(3)')[0].select('td:nth-of-type(2)')[0].select('div:nth-of-type(1)')[0].find('div', {'class':'row_info'}).string
        year = year.strip()
        return year
    except:
        return ''
    
def get_transmission(soup):
    try:
        trans = soup.body.find('div', {'id':'main_left'}).find('table', {'id':'carInfo'}).select('tr:nth-of-type(3)')[0].select('td:nth-of-type(2)')[0].find('div', {'class':'eachInfo'}).next_sibling.next_sibling.find('div', {'class':'row_info'}).string
        trans = trans.strip()
        return trans
    except:
        return ''

def get_omv(soup):
    try:
        tag = soup.body.find('div', {'id':'main_left'}).find('table', {'id':'carInfo'}).select('tr:nth-of-type(3)')[0].select('td:nth-of-type(2)')[0].select('div:nth-of-type(3)')[0].find('div', {'class':'row_title'}).text.strip()
        if tag == 'OMV':
            omv = soup.body.find('div', {'id':'main_left'}).find('table', {'id':'carInfo'}).select('tr:nth-of-type(3)')[0].select('td:nth-of-type(2)')[0].select('div:nth-of-type(3)')[0].find('div', {'class':'row_info'}).string
            omv = omv.strip()
        elif tag == 'Fuel Type':
            omv = soup.body.find('div', {'id':'main_left'}).find('table', {'id':'carInfo'}).select('tr:nth-of-type(3)')[0].select('td:nth-of-type(2)')[0].select('div:nth-of-type(4)')[0].find('div', {'class':'row_info'}).string
            omv = omv.strip()
        else:
            omv = 'NA'
        return omv
    except:
        return ''
    
def get_arf(soup):
    try:
        tag = soup.body.find('div', {'id':'main_left'}).find('table', {'id':'carInfo'}).select('tr:nth-of-type(3)')[0].select('td:nth-of-type(2)')[0].select('div:nth-of-type(4)')[0].find('div', {'class':'row_title'}).text.strip()
        if tag == 'ARF':
            arf = soup.body.find('div', {'id':'main_left'}).find('table', {'id':'carInfo'}).select('tr:nth-of-type(3)')[0].select('td:nth-of-type(2)')[0].select('div:nth-of-type(4)')[0].find('div', {'class':'row_info'}).string
            arf = arf.strip()
        elif tag == 'OMV':
            arf = soup.body.find('div', {'id':'main_left'}).find('table', {'id':'carInfo'}).select('tr:nth-of-type(3)')[0].select('td:nth-of-type(2)')[0].select('div:nth-of-type(5)')[0].find('div', {'class':'row_info'}).string
            arf = arf.strip()
        else:
            arf = 'NA'
        return arf
    except:
        return ''
    
def get_power(soup):
    try:
        tag = soup.body.find('div', {'id':'main_left'}).find('table', {'id':'carInfo'}).select('tr:nth-of-type(3)')[0].select('td:nth-of-type(2)')[0].select('div:nth-of-type(5)')[0].find('div', {'class':'row_title'}).text.strip()
        if tag == 'Power':
            power = soup.body.find('div', {'id':'main_left'}).find('table', {'id':'carInfo'}).select('tr:nth-of-type(3)')[0].select('td:nth-of-type(2)')[0].select('div:nth-of-type(5)')[0].find('div', {'class':'row_info'}).string
            power = power.strip()
        elif tag == 'ARF':
            power = soup.body.find('div', {'id':'main_left'}).find('table', {'id':'carInfo'}).select('tr:nth-of-type(3)')[0].select('td:nth-of-type(2)')[0].select('div:nth-of-type(6)')[0].find('div', {'class':'row_info'}).string
            power = power.strip()
        else:
            power = 'NA'
        return power
    except:
        return ''
    
def get_number_of_owner(soup):
    try:
        tag = soup.body.find('div', {'id':'main_left'}).find('table', {'id':'carInfo'}).select('tr:nth-of-type(3)')[0].select('td:nth-of-type(2)')[0].select('div:nth-of-type(6)')[0].find('div', {'class':'row_title'}).text.strip()
        if tag == 'No. of Owners':
            owner = soup.body.find('div', {'id':'main_left'}).find('table', {'id':'carInfo'}).select('tr:nth-of-type(3)')[0].select('td:nth-of-type(2)')[0].select('div:nth-of-type(6)')[0].find('div', {'class':'row_info'}).string
            owner = owner.strip()
        elif tag == 'Power':
            owner = soup.body.find('div', {'id':'main_left'}).find('table', {'id':'carInfo'}).select('tr:nth-of-type(3)')[0].select('td:nth-of-type(2)')[0].select('div:nth-of-type(7)')[0].find('div', {'class':'row_info'}).string
            owner = owner.strip()
        else:
            owner = 'NA'
        return owner
    except:
        return ''
    
def get_type(soup):
    try:
        typ = soup.body.find('div', {'id':'main_left'}).find('table', {'id':'carInfo'}).select('tr:nth-of-type(4)')[0].find('a').text
        typ = typ.strip()
    except:
        typ = soup.body.find('div', {'id':'main_left'}).find('table', {'id':'carInfo'}).select('tr:nth-of-type(3)')[0].find('td').select('div:nth-of-type(7)')[0].find('div', {'class':'row_info'}).text
        typ = typ.strip()   
    return typ

def get_all_other_info(soup):
    try:
        row = soup.body.find('div', {'id':'main_left'}).find('table', {'id':'carInfo'}).select('tr')
        # list of other info should return in this sequence [features, accessories, descriptions, category, status]
        other_info = ['NA', 'NA', 'NA', 'NA', 'NA']
    
        # get the rows info
        for i in range(5):
            position = i + 5
            row = soup.body.find('div', {'id':'main_left'}).find('table', {'id':'carInfo'}).select('tr:nth-of-type(%d)'%position)[0].find('td').text
            cleaned_row = ' '.join([t for t in (row.replace('\r', '').replace('\n','').strip().split(" ")) if len(t) > 0])
            if (cleaned_row.split(" ")[0] == 'Features'):
                other_info[0] = cleaned_row
            elif (cleaned_row.split(" ")[0] == 'Accessories'):
                other_info[1] = cleaned_row
            elif (cleaned_row.split(" ")[0] == 'Description'):
                other_info[2] = cleaned_row
            elif (cleaned_row.split(" ")[0] == 'Category'):
                other_info[3] = cleaned_row
            elif (cleaned_row.split(" ")[0] == 'Status'):
                other_info[4] = cleaned_row
            
        # somehow category and status data might not be read in do continue with the following
        if (other_info[1] == 'NA'):
            cat = soup.body.find('div', {'id':'main_left'}).find('table', {'id':'carInfo'}).select('tr:nth-of-type(7)')[0].find('td').text
            cleaned_cat = ' '.join([t for t in (cat.replace('\r', '').replace('\n','').replace('Status', '').strip().split(" ")) if len(t) > 0])
            other_info[3] = cleaned_cat
        
            stat = soup.body.find('div', {'id':'main_left'}).find('table', {'id':'carInfo'}).select('tr:nth-of-type(8)')[0].find('td').text
            cleaned_stat = ' '.join([t for t in (stat.replace('\r', '').replace('\n','').replace('Status', '').strip().split(" ")) if len(t) > 0])
            other_info[4] = cleaned_stat
        else:
            cat = soup.body.find('div', {'id':'main_left'}).find('table', {'id':'carInfo'}).select('tr:nth-of-type(8)')[0].find('td').text
            cleaned_cat = ' '.join([t for t in (cat.replace('\r', '').replace('\n','').replace('Status', '').strip().split(" ")) if len(t) > 0])
            other_info[3] = cleaned_cat
        
            stat = soup.body.find('div', {'id':'main_left'}).find('table', {'id':'carInfo'}).select('tr:nth-of-type(9)')[0].find('td').text
            cleaned_stat = ' '.join([t for t in (stat.replace('\r', '').replace('\n','').replace('Status', '').strip().split(" ")) if len(t) > 0])
            other_info[4] = cleaned_stat
        
        return other_info
    except:
        return '', '', '', '', ''


def get_postUpdate_date(soup):
    posted = ''
    updated = ''
    try:
        date = soup.body.find('div', {'id':'usedcar_postdate'}).get_text(strip=True).replace('\xa0', '').replace('\r', '').replace('\n', ''). replace('\t', '')
        posted = re.search('(?<=Posted on:).*?(?=\|)', date)[0].strip()
        updated = re.search('(?<=Updated on:).*', date)[0].strip()
    except:
        pass
    
    return posted, updated

# %%
# scrape html data from text file
# read a text file in format of .txt which contains html text
def feature_scraping(filePath):

    # read the file
    with open(filePath, 'r') as file:
        html_content = file.read()
        
    print(filePath)

    # read the html content with BS4
    soup = BeautifulSoup(html_content)

    # scrape standard features
    model = get_model(soup)
    price = get_price(soup)
    depreciation = get_depreciation(soup)
    reg_date = get_registrationDate(soup)
    manufactured_year = get_manufacturedYear(soup)
    mileage = get_mileage(soup)
    road_tax = get_roadTax(soup)
    transmission = get_transmission(soup)
    dereg_value = get_deregistrationValue(soup)
    omv = get_omv(soup)
    coe = get_coe(soup)
    arf = get_arf(soup)
    engine_cap = get_engineCap(soup)
    power = get_power(soup)
    curb_weight = get_curbWeight(soup)
    number_of_owner = get_number_of_owner(soup)
    types = get_type(soup)

    # scrape other features
    other_info  = get_all_other_info(soup)
    features = other_info[0]
    accessories = other_info[1]
    descriptions = other_info[2]
    category = other_info[3]
    status = other_info[4]

    return model, price, depreciation, reg_date, manufactured_year, mileage, road_tax, transmission, dereg_value, omv, coe, arf, engine_cap, power, curb_weight, number_of_owner, types, features, accessories, descriptions, category, status

# %%
# scrape html data from text file
# read a text file in format of .txt which contains html text
def feature_scraping(filePath):

    # read the file
    with open(filePath, 'r') as file:
        html_content = file.read()
        
    print(filePath)

    # read the html content with BS4
    soup = BeautifulSoup(html_content)

    # scrape standard features
    model = get_model(soup)
    price = get_price(soup)
    depreciation = get_depreciation(soup)
    reg_date = get_registrationDate(soup)
    manufactured_year = get_manufacturedYear(soup)
    mileage = get_mileage(soup)
    road_tax = get_roadTax(soup)
    transmission = get_transmission(soup)
    dereg_value = get_deregistrationValue(soup)
    omv = get_omv(soup)
    coe = get_coe(soup)
    arf = get_arf(soup)
    engine_cap = get_engineCap(soup)
    power = get_power(soup)
    curb_weight = get_curbWeight(soup)
    number_of_owner = get_number_of_owner(soup)
    types = get_type(soup)

    # scrape other features
    other_info  = get_all_other_info(soup)
    features = other_info[0]
    accessories = other_info[1]
    descriptions = other_info[2]
    category = other_info[3]
    status = other_info[4]
    
    # scrape posted and updated date
    posted_date = get_postUpdate_date(soup)[0]
    updated_date = get_postUpdate_date(soup)[1]

    return model, price, depreciation, reg_date, manufactured_year, mileage, road_tax, transmission, dereg_value, omv, coe, arf, engine_cap, power, curb_weight, number_of_owner, types, features, accessories, descriptions, category, status, posted_date, updated_date

# %%
def scrape_directory(directory_path):
    results = []
    for file_name in os.listdir(directory_path):
        if file_name.endswith('.html'):
            file_path = os.path.join(directory_path, file_name)
            if os.path.isfile(file_path):
                result = feature_scraping(file_path)
                results.append(result)
            else:
                print(f'Error: {file_path} is not a valid file path')
    return results

# %%
# combine the feature scraping function with the pathList
# NOTE: do replace [path] in the map function with a list of file directory\
directory_path = r'Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418'
# %time sgCarMart_features = scrape_directory(directory_path)
#%time sgCarMart_features = list(map(scrape_directory, [directory_path]))
# Out:
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_22-57-05.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_22-55-38.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_02-12-22.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-23-25.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-21-18.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_23-20-39.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-54-19.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-56-24.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_22-43-46.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_22-47-05.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-15-16.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_22-45-38.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-33-25.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-31-18.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_22-53-46.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-44-19.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-01-11.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_23-08-50.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_23-00-30.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-37-22.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_23-10-30.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-05-52.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-22-08.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-20-35.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_02-11-32.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_22-48-36.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_22-54-15.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-28-55.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-55-34.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-57-09.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_23-21-14.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-32-08.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-30-35.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_22-46-28.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-16-06.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_22-44-15.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_02-01-32.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_22-58-36.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-59-17.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_02-09-52.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-38-55.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-59-53.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-38-11.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-02-01.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_23-03-20.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-06-42.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-27-31.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_22-53-11.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-52-30.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_02-00-48.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-15-41.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_22-47-52.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-37-31.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_02-06-36.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_22-43-11.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_22-57-52.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_02-10-48.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-42-30.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-23-36.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-07-38.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-05-05.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-35-48.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_23-18-07.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_23-04-24.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_23-06-19.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-56-37.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-33-36.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_23-14-24.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_23-16-19.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-58-29.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_23-08-07.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_02-09-05.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-38-02.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-24-21.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-59-40.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_22-44-42.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-16-51.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_02-03-58.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_23-21-43.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_02-05-26.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-34-21.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-28-02.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-41-20.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_22-54-42.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-06-15.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-04-28.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-20-26.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_23-07-34.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-36-58.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-38-46.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-02-56.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-59-04.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_23-15-09.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_23-17-34.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-42-26.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-21-59.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_22-57-44.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-54-58.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_22-43-07.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_02-06-20.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-37-27.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-29-39.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-31-59.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_22-47-44.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-52-26.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_22-53-07.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-27-27.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-01-50.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_23-08-11.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_23-14-32.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-33-20.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_23-04-32.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-56-21.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_23-18-11.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-05-13.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-23-20.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_22-54-54.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-22-49.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-41-36.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-28-14.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-34-37.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_02-05-30.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_23-21-55.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-57-48.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-16-47.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-32-49.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-59-56.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_02-09-13.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_22-50-17.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_23-17-22.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-59-12.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-02-40.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-38-50.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-55-31.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_23-07-22.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-20-30.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-06-03.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_22-53-50.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-33-33.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_22-47-13.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-15-00.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_02-00-09.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_02-02-34.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_22-43-50.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-23-33.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_02-10-09.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-19-23.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_02-12-34.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_22-57-13.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-05-44.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_23-10-26.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-37-34.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-35-09.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_23-06-58.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_23-18-46.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_23-00-26.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_23-08-46.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_23-16-58.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-25-09.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-01-07.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-38-43.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_22-50-40.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_02-09-44.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_02-01-24.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_22-58-20.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_02-03-19.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_22-44-03.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-30-23.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_23-21-02.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-55-22.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-28-43.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_22-54-03.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_02-11-24.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_02-13-19.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_22-48-20.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_23-05-48.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-36-19.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-34-24.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_23-03-36.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-02-17.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-24-24.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_23-15-48.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-59-45.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-21-31.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-07-02.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_23-06-23.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-58-13.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_23-16-23.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-03-41.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-39-51.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-58-57.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-39-15.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-25-36.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_02-08-12.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_22-45-55.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-33-48.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-35-36.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-29-15.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_22-41-16.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_02-04-31.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_23-20-54.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-56-49.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-19-58.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_22-55-55.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-23-48.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-40-37.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-04-12.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_23-19-10.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_23-05-33.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-57-20.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-32-21.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-00-51.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_23-15-33.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_23-09-10.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_22-52-06.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-26-26.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-38-38.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-30-58.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-14-56.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_22-46-45.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-53-27.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-55-59.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-36-26.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-43-27.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_22-56-45.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-03-16.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-25-25.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-39-06.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-58-44.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_23-14-49.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_23-02-37.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_23-04-49.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-37-18.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-35-25.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-07-55.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_02-10-25.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_22-49-21.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_22-55-02.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-21-22.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_23-20-03.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-54-23.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-29-42.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_22-41-41.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-17-11.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_22-45-02.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_02-00-25.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_02-02-18.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_22-59-21.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-31-22.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_22-51-41.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_02-08-45.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-44-23.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-58-00.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_23-17-59.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_23-09-47.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-24-08.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-00-06.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_23-01-27.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-36-35.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-34-08.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_23-19-47.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_23-07-59.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_23-11-27.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-22-32.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_22-56-12.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_02-11-08.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-18-22.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_22-42-51.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-32-32.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_02-01-08.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_02-03-35.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_22-46-12.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_22-52-51.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-07-43.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_23-12-21.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-35-33.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_23-02-21.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-58-52.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-25-33.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-03-00.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-58-16.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-44-35.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_22-51-57.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_02-08-53.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-33-09.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-31-34.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_02-00-33.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_22-59-37.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_22-47-29.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_22-45-14.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-29-54.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-56-08.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_23-20-15.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-23-09.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_22-57-29.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_22-55-14.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_02-10-33.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-19-19.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_22-49-37.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-04-53.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_23-19-51.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-36-23.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_23-01-31.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-00-10.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_22-52-47.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_22-46-04.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_22-44-39.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_02-03-23.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-32-24.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-30-19.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_23-21-38.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-57-25.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_22-42-47.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-18-34.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_22-54-39.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-22-24.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-39-47.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-03-57.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_23-16-35.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-58-05.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_23-04-08.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-37-59.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-07-14.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-05-29.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-21-27.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-40-21.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_22-55-43.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_02-12-59.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_23-20-42.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_02-04-27.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_22-41-00.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_02-02-59.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_22-45-43.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-17-50.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_02-08-04.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_22-51-00.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-25-20.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-39-03.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-59-28.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_23-09-06.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_23-15-25.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_23-17-18.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-34-49.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_23-05-25.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_23-07-18.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_23-19-06.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-22-37.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-06-39.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-04-04.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_02-11-49.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_22-56-53.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-43-31.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_02-07-37.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-53-31.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-14-40.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_22-46-53.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_02-01-49.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-26-30.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_22-52-10.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-38-59.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-26-47.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-14-37.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_22-44-19.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_22-46-24.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_02-03-03.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-30-39.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-32-04.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-53-46.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-57-05.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-55-38.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-36-47.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-28-59.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_02-07-40.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-43-46.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-18-14.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_02-13-03.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_22-54-19.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-20-39.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-22-04.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_23-11-11.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-22-40.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_23-05-52.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-57-41.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-36-03.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-32-40.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-00-30.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_23-15-52.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-58-36.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-44-15.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-25-57.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-31-14.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-33-29.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_22-59-17.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_22-45-34.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_22-47-09.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_02-04-50.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-35-57.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-56-28.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_23-20-35.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-21-14.html
# ...
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_23-20-00.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-54-20.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-29-41.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_02-06-58.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-56-59.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-35-26.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_23-10-09.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_23-12-34.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-23-58.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-07-56.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-03-15.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-01-28.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-39-05.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-25-26.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-58-47.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-33-58.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_23-00-09.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_23-02-34.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-32-31.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_22-46-11.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_02-03-36.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_22-52-52.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-22-31.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-18-21.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_22-56-11.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_22-42-52.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_02-05-48.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-57-30.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-36-36.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-55-49.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_23-19-44.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-04-46.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-20-48.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_23-11-24.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_23-13-19.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_23-09-44.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-38-28.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-00-05.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_23-01-24.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_23-03-19.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_22-41-54.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-37-49.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-29-57.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_23-20-16.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-21-37.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_02-10-30.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_22-49-34.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_22-55-17.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-42-48.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-44-36.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_02-08-50.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-27-49.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-52-48.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-31-37.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-17-04.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_22-45-17.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-15-39.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_02-00-30.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_22-59-34.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_23-02-22.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-58-51.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-25-30.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-39-13.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-03-03.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-07-40.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_23-12-22.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-35-30.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-57-26.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-34-59.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_22-42-44.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-41-58.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_22-56-07.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_22-48-19.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_02-13-20.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-18-37.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-22-27.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-24-59.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_22-52-44.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-59-38.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_02-03-20.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_22-58-19.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-16-29.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_22-46-07.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-32-27.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_23-01-32.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-00-13.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_23-11-32.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-04-50.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-36-20.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_22-45-40.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-17-53.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_02-08-07.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_22-51-03.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-39-00.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-25-23.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-58-42.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-40-22.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_22-55-40.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_23-20-41.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_22-41-03.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_02-06-19.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-35-23.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-29-00.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-56-18.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_23-18-28.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_23-10-48.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-23-19.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-21-24.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-39-44.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-03-54.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_23-08-28.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-58-06.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_23-16-36.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-33-19.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_23-00-48.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-53-32.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_22-46-50.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-26-33.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_22-56-50.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-43-32.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-36-33.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_02-07-34.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_23-19-05.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_23-05-26.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-22-34.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-20-09.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-04-07.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_23-15-26.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_23-09-05.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_01-00-44.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-17_23-03-58.html
# Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\html_files\0417_0418\car_html_content_2023-04-18_00-32-34.html
# CPU times: total: 19min 55s
# Wall time: 20min 26s

# %%
# transform to dataframe
df = pd.DataFrame(sgCarMart_features,
                 columns = ['model', 'price', 'depreciation', 'registration_date', 'manufactured_year', 'mileage', 'road_tax', 'transmission', 'deregistration_value', 'omv', 'coe', 'arf', 'engine_cap', 'power', 'curb_weight', 'number_of_owner', 'types', 'features', 'accessories', 'descriptions', 'category', 'status', 'posted_date', 'updated_date'])
df.head()
# Out:
#                                                model     price depreciation  \
# 0         Mercedes-Benz Viano CDI (COE till 09/2027)   $88,000      $19,740
# 1  Audi S4 3.0A TFSI Quattro S-tronic (COE till 0...  $108,800      $17,060
# 2                     Subaru Forester 2.0i-L Sunroof       N.A          N.A
# 3                               Toyota Hiace 2.8A DX   $90,800      $11,580
# 4              Toyota Mark X 2.5A (COE till 05/2026)   $44,000      $14,090
#
#   registration_date manufactured_year                 mileage    road_tax  \
# 0       21-Nov-2012              2012  206,227 km (19.8k /yr)        N.A.
# 1       06-Oct-2009              2009  166,000 km (12.3k /yr)  $3,332 /yr
# 2       28-Apr-2017              2017                    N.A.  $1,208 /yr
# 3       18-Feb-2021              2020                    N.A.        N.A.
# 4       08-Jun-2006              2006  172,000 km (10.2k /yr)  $2,697 /yr
#
#   transmission deregistration_value      omv  ... curb_weight number_of_owner  \
# 0         Auto              $24,523  $46,658  ...    2,280 kg               2
# 1         Auto              $25,472  $62,346  ...    1,685 kg     More than 6
# 2         Auto                 N.A.  $14,556  ...    1,591 kg               1
# 3         Auto              $26,900  $35,445  ...    1,800 kg               1
# 4         Auto              $14,369  $29,495  ...    1,500 kg               4
#
#           types                                           features  \
# 0  Bus/Mini Bus
# 1    Sports Car  Features Powerful 3.0L V6 supercharged engine ...
# 2           SUV  Features 2.0l 4 Cylinders DOHC Horizontally Op...
# 3           Van            Features View specs of the Toyota Hiace
# 4  Luxury Sedan  Features No dealers, no consignment. Negotiabl...
#
#                                          accessories  \
# 0
# 1  Accessories Upgraded head unit, leather seats ...
# 2  Accessories Leather Electric Seats, Panoramic ...
# 3                                                 NA
# 4  Accessories 211hp, 260nm torque, 4.1 final dri...
#
#                                         descriptions  \
# 0
# 1  Description Unit super well taken care by curr...
# 2  Description Fully agent maintained. Free 3 yea...
# 3    Description Hiace auto diesel with rear aircon.
# 4  Description Easy maintenance 4GR-FSE, custom i...
#
#                              category  \
# 0
# 1     CategoryCOE Car, Premium Ad Car
# 2                    CategoryPARF Car
# 3              CategoryPremium Ad Car
# 4  CategoryCOE Car, Direct Owner Sale
#
#                                               status  posted_date updated_date
# 0                                                     15-Apr-2023  15-Apr-2023
# 1  Available for sale. Shortlist this car to get ...  15-Apr-2023  15-Apr-2023
# 2                                               SOLD  24-Mar-2023  16-Apr-2023
# 3  Available for sale. Shortlist this car to get ...  03-Apr-2023  10-Apr-2023
# 4  Available for sale. Shortlist this car to get ...  04-Apr-2023  15-Apr-2023
#
# [5 rows x 24 columns]

# %%
# write the scraped data to a CSV file
df.to_csv('Y:\Documents\GitHub\CarSmartConsultancy\Data\scrape_data\sgCarMart_features+2dates.csv', index=False)
